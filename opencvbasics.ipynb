# %%
import cv2

# %%
from matplotlib import pyplot as plt

# %%
#plotting img

# %%
img1=cv2.imread("Resources/Data/lena.png",0)
plt.imshow(img1)

# %%
#arithmetic operation

# %%
img2=cv2.imread("Resources/Data/baboon.jpg",0)
result=img1+img2
plt.imshow(result)
#addition of two images

# %%
result=img1-img2
plt.imshow(result)

# %%
result=img1*img2
plt.imshow(result)

# %%
result=img1/img2
plt.imshow(result)
# Out:
# C:\Users\nikhi\AppData\Local\Temp\ipykernel_13728\1580248168.py:1: RuntimeWarning: divide by zero encountered in divide
#   result=img1/img2

# %%
img1=cv2.imread("Resources/Data/brain.jpg")
img=cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2RGB)),plt.title("blurred")
plt.xticks([]),plt.yticks([])
# Out:
# (([], []), ([], []))

# %%
img1=cv2.imread("Resources/Data/lena.png")

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
import cv2
import matplotlib.pyplot as plt

# Read image
img1 = cv2.imread("Resources/Data/lena.png")

# Get height and width
(height, width) = img1.shape[:2]

# Resize image to 2x
zoom = cv2.resize(
    img1,
    (2 * width, 2 * height),
    interpolation=cv2.INTER_CUBIC
)

# Convert BGR to RGB for matplotlib
zoom_rgb = cv2.cvtColor(zoom, cv2.COLOR_BGR2RGB)

# Display image
plt.imshow(zoom_rgb)
plt.axis("off")
plt.show()

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %%
import numpy as np
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img1,m,(height,width))
plt.imshow(dst)
